# %%
# Dependencies
import pandas as pd
import csv
import requests
from pprint import pprint
from scipy.stats import linregress
import matplotlib.pyplot as plt
import numpy as np
from sodapy import Socrata
import os
import gmaps
from config import api_key

# %%
# Data collection - year 2021 - during-covid

client = Socrata("data.melbourne.vic.gov.au", app_token="Mp9xM2ztPtLxPmpOj2ZhhkFYm", username="angelaliu0101@gmail.com", password="Lh*19630722")

results_2021 = client.get("b2ak-trbp", year= 2021, limit = 10000000)

results_2021_df = pd.DataFrame.from_records(results_2021)
results_2021_mor_df = pd.DataFrame.from_records(results_2021)
results_2021_md_df = pd.DataFrame.from_records(results_2021)
results_2021_eve_df = pd.DataFrame.from_records(results_2021)

results_2021_df.to_csv("foottrafficsdata2021.csv")
results_2021_mor_df.to_csv("foottrafficsdata2021.csv")
results_2021_md_df.to_csv("foottrafficsdata2021.csv")
results_2021_eve_df.to_csv("foottrafficsdata2021.csv")
results_2021_df.head()
# Out:
#         id                date_time  year    month mdate     day time  \
# 0  3482939  2021-01-01T00:00:00.000  2021  January     1  Friday    0
# 1  3482940  2021-01-01T00:00:00.000  2021  January     1  Friday    0
# 2  3482941  2021-01-01T00:00:00.000  2021  January     1  Friday    0
# 3  3482942  2021-01-01T00:00:00.000  2021  January     1  Friday    0
# 4  3482943  2021-01-01T00:00:00.000  2021  January     1  Friday    0
#
#   sensor_id                 sensor_name hourly_counts
# 0         4            Town Hall (West)          1461
# 1        17       Collins Place (South)            79
# 2        18       Collins Place (North)            33
# 3        53          Collins St (North)           196
# 4         2  Bourke Street Mall (South)           236

# %%
# Data 2021 cleaning - data types

results_2021_df.dtypes
# Out:
# id               object
# date_time        object
# year             object
# month            object
# mdate            object
# day              object
# time             object
# sensor_id        object
# sensor_name      object
# hourly_counts    object
# dtype: object

# %%
# Data 2021 cleaning - data types
data_type_dict = {"id":int,"year":int,"mdate":int,"time":int,"hourly_counts":float}
results_2021_df = results_2021_df.astype(data_type_dict)
results_2021_mor_df = results_2021_df.astype(data_type_dict)
results_2021_md_df = results_2021_df.astype(data_type_dict)
results_2021_eve_df = results_2021_df.astype(data_type_dict)
results_2021_df.dtypes
results_2021_df.to_csv('DATA.csv',index=False)

# %%
# morning Data 2021 groupby sum
results_2021_mor_df= results_2021_df[(results_2021_mor_df["time"] >= 7) & (results_2021_mor_df["time"] <= 10)]
location = results_2021_mor_df.groupby("sensor_name")
foottrafic_2021 = location["hourly_counts"].sum()

results_2021_mor_groupby_df = pd.DataFrame({"Midday foottrafic 2021": foottrafic_2021})
results_2021_mor_groupby_df = results_2021_mor_groupby_df.reset_index()
results_2021_mor_groupby_df.rename(columns={"sensor_name":"location"},inplace=True)
results_2021_mor_groupby_df
# Out:
#                           location  Midday foottrafic 2021
# 0                    231 Bourke St                314431.0
# 1                     Alfred Place                103961.0
# 2                   Birrarung Marr                257212.0
# 3   Bourke St - Spencer St (North)                510439.0
# 4   Bourke St - Spencer St (South)                 25326.0
# ..                             ...                     ...
# 77                Town Hall (West)                704760.0
# 78                  Victoria Point                 73071.0
# 79                 Waterfront City                 58041.0
# 80                     Webb Bridge                251578.0
# 81                  Westwood Place                 68801.0
#
# [82 rows x 2 columns]

# %%
# morning Data 2021 groupby mean & std

results_2021_mor_df= results_2021_mor_df[(results_2021_mor_df["time"] >= 7) & (results_2021_mor_df["time"] <= 10)]
location = results_2021_mor_df.groupby("sensor_name")
foottrafic_2021_mor = location["hourly_counts"].describe()

foottrafic_2021_mor
# Out:
#                                  count        mean         std   min     25%  \
# sensor_name
# 231 Bourke St                   1328.0  236.770331  119.449393   0.0  147.00
# Alfred Place                    1452.0   71.598485   59.865361   1.0   26.00
# Birrarung Marr                  1460.0  176.172603  160.816957  10.0  106.00
# Bourke St - Spencer St (North)  1460.0  349.615753  292.462820   2.0  116.75
# Bourke St - Spencer St (South)   248.0  102.120968   81.451319   4.0   37.75
# ...                                ...         ...         ...   ...     ...
# Town Hall (West)                1460.0  482.712329  332.507044  34.0  229.00
# Victoria Point                  1440.0   50.743750   46.344770   0.0   12.00
# Waterfront City                 1460.0   39.754110   21.111258   0.0   25.75
# Webb Bridge                     1460.0  172.313699   77.924923   0.0  124.00
# Westwood Place                  1460.0   47.123973   48.321324   0.0   18.00
#
#                                   50%     75%     max
# sensor_name
# 231 Bourke St                   232.5  309.00   740.0
# Alfred Place                     48.0  107.00   323.0
# Birrarung Marr                  151.0  212.00  3801.0
# Bourke St - Spencer St (North)  270.0  508.00  1628.0
# Bourke St - Spencer St (South)   81.5  146.25   427.0
# ...                               ...     ...     ...
# Town Hall (West)                354.5  703.75  1649.0
# Victoria Point                   40.0   73.00   269.0
# Waterfront City                  37.0   51.00   143.0
# Webb Bridge                     165.0  211.00   603.0
# Westwood Place                   38.0   64.00  1109.0
#
# [82 rows x 8 columns]

# %%
# midday Data 2021 groupby sum
results_2021_md_df= results_2021_df[(results_2021_md_df["time"] >= 12) & (results_2021_md_df["time"] <= 15)]
location = results_2021_md_df.groupby("sensor_name")
foottrafic_2021 = location["hourly_counts"].sum()

results_2021_md_groupby_df = pd.DataFrame({"Midday foottrafic 2021": foottrafic_2021})
results_2021_md_groupby_df = results_2021_md_groupby_df.reset_index()
results_2021_md_groupby_df.rename(columns={"sensor_name":"location"},inplace=True)
results_2021_md_groupby_df
# Out:
#                           location  Midday foottrafic 2021
# 0                    231 Bourke St                729886.0
# 1                     Alfred Place                185084.0
# 2                   Birrarung Marr                320080.0
# 3   Bourke St - Spencer St (North)                641481.0
# 4   Bourke St - Spencer St (South)                 33935.0
# ..                             ...                     ...
# 77                Town Hall (West)               2264144.0
# 78                  Victoria Point                 80716.0
# 79                 Waterfront City                 91380.0
# 80                     Webb Bridge                355120.0
# 81                  Westwood Place                 52644.0
#
# [82 rows x 2 columns]

# %%
# midday Data 2021 groupby mean & std

results_2021_md_df= results_2021_md_df[(results_2021_md_df["time"] >= 12) & (results_2021_md_df["time"] <= 15)]
location = results_2021_md_df.groupby("sensor_name")
foottrafic_2021_md = location["hourly_counts"].describe()

foottrafic_2021_md
# Out:
#                                  count         mean         std    min  \
# sensor_name
# 231 Bourke St                   1328.0   549.612952  278.569425  105.0
# Alfred Place                    1452.0   127.468320  112.177058    2.0
# Birrarung Marr                  1460.0   219.232877  256.215536   10.0
# Bourke St - Spencer St (North)  1460.0   439.370548  251.192160   10.0
# Bourke St - Spencer St (South)   248.0   136.834677   70.963246   22.0
# ...                                ...          ...         ...    ...
# Town Hall (West)                1460.0  1550.783562  792.553706   56.0
# Victoria Point                  1440.0    56.052778   45.043720    0.0
# Waterfront City                 1460.0    62.589041   41.174526    1.0
# Webb Bridge                     1460.0   243.232877   99.758223    0.0
# Westwood Place                  1460.0    36.057534   36.500135    0.0
#
#                                    25%     50%      75%     max
# sensor_name
# 231 Bourke St                   352.75   508.0   685.25  3874.0
# Alfred Place                     47.00    83.5   169.25   562.0
# Birrarung Marr                  113.00   154.0   238.00  4067.0
# Bourke St - Spencer St (North)  176.75   454.5   617.00  1478.0
# Bourke St - Spencer St (South)   80.00   127.0   192.25   321.0
# ...                                ...     ...      ...     ...
# Town Hall (West)                648.50  1660.5  2109.00  3694.0
# Victoria Point                   22.00    46.0    79.00   271.0
# Waterfront City                  36.00    53.0    79.00   401.0
# Webb Bridge                     180.00   227.0   299.25  1158.0
# Westwood Place                   13.00    23.0    47.00   424.0
#
# [82 rows x 8 columns]

# %%
# evening Data 2021 groupby sum
results_2021_eve_df= results_2021_df[(results_2021_eve_df["time"] >= 18) & (results_2021_eve_df["time"] <= 21)]
location = results_2021_eve_df.groupby("sensor_name")
foottrafic_2021 = location["hourly_counts"].sum()

results_2021_eve_groupby_df = pd.DataFrame({"Midday foottrafic 2021": foottrafic_2021})
results_2021_eve_groupby_df = results_2021_eve_groupby_df.reset_index()
results_2021_eve_groupby_df.rename(columns={"sensor_name":"location"},inplace=True)
results_2021_eve_groupby_df
# Out:
#                           location  Midday foottrafic 2021
# 0                    231 Bourke St                387401.0
# 1                     Alfred Place                 53993.0
# 2                   Birrarung Marr                302147.0
# 3   Bourke St - Spencer St (North)                397611.0
# 4   Bourke St - Spencer St (South)                 22626.0
# ..                             ...                     ...
# 77                Town Hall (West)               1269141.0
# 78                  Victoria Point                 66826.0
# 79                 Waterfront City                114690.0
# 80                     Webb Bridge                200071.0
# 81                  Westwood Place                 50774.0
#
# [82 rows x 2 columns]

# %%
# evening Data 2021 groupby mean & std

results_2021_eve_df= results_2021_eve_df[(results_2021_eve_df["time"] >= 18) & (results_2021_eve_df["time"] <= 21)]
location = results_2021_eve_df.groupby("sensor_name")
foottrafic_2021_eve = location["hourly_counts"].describe()

foottrafic_2021_eve
# Out:
#                                  count        mean         std   min     25%  \
# sensor_name
# 231 Bourke St                   1328.0  291.717620  208.221614   1.0  130.75
# Alfred Place                    1452.0   37.185262   31.251025   0.0   13.00
# Birrarung Marr                  1460.0  206.950000  377.537183   0.0   50.00
# Bourke St - Spencer St (North)  1460.0  272.336301  214.993447   0.0  111.00
# Bourke St - Spencer St (South)   248.0   91.233871   61.382402   0.0   54.00
# ...                                ...         ...         ...   ...     ...
# Town Hall (West)                1460.0  869.274658  639.199899  21.0  328.00
# Victoria Point                  1440.0   46.406944   43.021235   0.0   15.00
# Waterfront City                 1460.0   78.554795   50.870736   0.0   41.00
# Webb Bridge                     1460.0  137.034932   98.138441   0.0   60.00
# Westwood Place                  1460.0   34.776712   32.323621   0.0   10.00
#
#                                   50%      75%     max
# sensor_name
# 231 Bourke St                   250.0   415.00  1243.0
# Alfred Place                     28.0    54.00   197.0
# Birrarung Marr                  103.0   208.00  5496.0
# Bourke St - Spencer St (North)  236.0   357.00  1492.0
# Bourke St - Spencer St (South)   78.0   108.25   425.0
# ...                               ...      ...     ...
# Town Hall (West)                753.0  1295.25  3757.0
# Victoria Point                   38.0    62.00   342.0
# Waterfront City                  72.0   109.00   511.0
# Webb Bridge                     116.0   201.00   528.0
# Westwood Place                   25.0    51.00   236.0
#
# [82 rows x 8 columns]

# %%
# weekly average pedistrain at Town Hall
data_wk = pd.read_csv('./foottrafficsdata2021.csv')
data_wk = data_wk[['id','date_time','year','month','mdate','day','time','sensor_id','sensor_name','hourly_counts']]
#selected area
point='231 Bourke St'
data_wk=data_wk[data_wk['sensor_name']==point]
weeks=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
mors=[]
noons=[]
eves=[]
means=[]
for month in weeks:
    month_data=data_wk.groupby('day').get_group(month)
    mors.append(month_data[month_data['time'].between(7, 10)].hourly_counts.sum()/30)
    noons.append(month_data[month_data['time'].between(12, 15)].hourly_counts.sum()/30)
    eves.append(month_data[month_data['time'].between(18, 21)].hourly_counts.sum()/30)
    means.append(month_data.hourly_counts.sum()/30)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(18,10))
x = weeks
y1 = np.array(eves)
y2 = np.array(noons)
y3 = np.array(mors)
  
plt.bar(x, y1, bottom=0,label='Evening', width=0.67)
plt.bar(x, y2, bottom=y1, label='Noon', width=0.67)
plt.bar(x, y3, bottom=y1+y2, label='Morning', width=0.67)
ax=plt.gca()
ax2 = ax.twinx()
ax2.plot(x,[x for x in means],c='g',label='Mean')#devide by 3,the mean of each day per session
plt.xlabel("Month",size=20)
ax.set_ylabel("Period")
ax2.set_ylabel("Total")
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title("The average weeksy population in "+point)
# plt.tight_layout()
plt.show()

# %%
# monthly pedistrain comparison at 231 bourke st # most visited site 
data_mt = pd.read_csv('./foottrafficsdata2021.csv')
data_mt = data_mt[['id','date_time','year','month','mdate','day','time','sensor_id','sensor_name','hourly_counts']]
#selected area
point='231 Bourke St'
data_mt=data_mt[data_mt['sensor_name']==point]
months=['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
mors=[]
noons=[]
eves=[]
means=[]
for month in months:
    month_data=data_mt.groupby('month').get_group(month)
    mors.append(month_data[month_data['time'].between(7, 10)].hourly_counts.sum()/30)
    noons.append(month_data[month_data['time'].between(12, 15)].hourly_counts.sum()/30)
    eves.append(month_data[month_data['time'].between(18, 21)].hourly_counts.sum()/30)
    means.append(month_data.hourly_counts.sum()/30)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(18,10))
x = months
y1 = np.array(eves)
y2 = np.array(noons)
y3 = np.array(mors)
  
plt.bar(x, y1, bottom=0,label='Evening', width=0.67)
plt.bar(x, y2, bottom=y1, label='Noon', width=0.67)
plt.bar(x, y3, bottom=y1+y2, label='Morning', width=0.67)
ax=plt.gca()
ax2 = ax.twinx()
ax2.plot(x,[x for x in means],c='g',label='Mean') #/3 average in each month per session
plt.xlabel("Month",size=20)
ax.set_ylabel("Period")
ax2.set_ylabel("Total")
ax.legend()
ax2.legend(loc='upper right')
plt.title("The average monthly population in "+point)
# plt.tight_layout()
plt.show()

# %%
# Getting location coordinate

Location_list = results_2021_md_groupby_df["location"].tolist()

location = []
latitude = []
longitude = []

for i in Location_list:
    try:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json"
        target_location2 = i + ", Melbourne"
    
        params = {"address": target_location2, "key": api_key}
        response = requests.get(base_url, params=params)
        location_geo = response.json()
        lat = location_geo["results"][0]["geometry"]["location"]["lat"]
        lng = location_geo["results"][0]["geometry"]["location"]["lng"]
        print(f"{target_location2}: {lat}, {lng}")
        location.append(i)
        latitude.append(lat)
        longitude.append(lng)
    except:
        print("Target location not found")
# Out:
# 231 Bourke St, Melbourne: -37.8133992, 144.9668301
# Alfred Place, Melbourne: -37.8143404, 144.9701942
# Birrarung Marr, Melbourne: -37.8187351, 144.9742624
# Bourke St - Spencer St (North), Melbourne: -37.8170606, 144.9533436
# Bourke St - Spencer St (South), Melbourne: -37.8171069, 144.9531785
# Bourke St Bridge, Melbourne: -37.8159602, 144.9572025
# Bourke St-Russell St (West), Melbourne: -37.8159602, 144.9572025
# Bourke Street Mall (North), Melbourne: -37.8137685, 144.9644379
# Bourke Street Mall (South), Melbourne: -37.8137685, 144.9644379
# Chinatown-Lt Bourke St (South), Melbourne: -37.8132372, 144.9627782
# Chinatown-Swanston St (North), Melbourne: -37.8058235, 144.9631138
# Collins Place (North), Melbourne: -37.8144674, 144.9733256
# Collins Place (South), Melbourne: -37.8144674, 144.9733256
# Collins St (North), Melbourne: -37.8182937, 144.956676
# Elizabeth St-La Trobe St (East), Melbourne: -37.8102887, 144.9614233
# Elizabeth St-Lonsdale St (South), Melbourne: -37.8122041, 144.962311
# Errol Street (East), Melbourne: -37.8012559, 144.9500134
# Faraday St-Lygon St (West), Melbourne: -37.7986322, 144.9673519
# Flinders La-Swanston St (West), Melbourne: -37.8164851, 144.9669885
# Flinders Ln - Degraves St (Crossing), Melbourne: -37.8168836, 144.9656031
# Flinders Ln - Degraves St (North), Melbourne: -37.8168836, 144.9656031
# Flinders Ln - Degraves St (South), Melbourne: -37.8168836, 144.9656031
# Flinders Ln -Degraves St (Crossing), Melbourne: -37.8168836, 144.9656031
# Flinders Ln -Degraves St (North), Melbourne: -37.8168836, 144.9656031
# Flinders Ln -Degraves St (South), Melbourne: -37.8168836, 144.9656031
# Flinders St (South), Melbourne: -37.8185815, 144.9637799
# Flinders St - ACMI, Melbourne: -37.8175974, 144.9686881
# Flinders St-ACMI, Melbourne: -37.8175974, 144.9686881
# Flinders St-Elizabeth St (East), Melbourne: -37.8181479, 144.9648712
# Flinders St-Spark La, Melbourne: -37.81557979999999, 144.9736114
# Flinders Street Station Underpass, Melbourne: -37.8182711, 144.9670618
# Grattan St-Swanston St (West), Melbourne: -37.8003998, 144.9638985
# Harbour Esplanade (West) - Bike Path, Melbourne: -37.8514722, 144.9681887
# Harbour Esplanade (West) - Ped Path, Melbourne: -37.8174417, 144.9459303
# Harbour Esplanade (West) - Pedestrian Pa, Melbourne: -37.8174417, 144.9459303
# La Trobe St (North), Melbourne: -37.8112453, 144.9581501
# Lincoln-Swanston(West), Melbourne: 28.0716832, -80.65338779999999
# Little Collins St-Swanston St (East), Melbourne: -37.8145013, 144.966084
# Lonsdale St (South), Melbourne: -37.8122489, 144.9621762
# Lonsdale St - Elizabeth St (North), Melbourne: -37.8122489, 144.9621762
# Lonsdale St-Spring St (West), Melbourne: -37.8093454, 144.9720377
# Lygon St (East), Melbourne: -37.7844784, 144.9697077
# Lygon St (West), Melbourne: -37.7844784, 144.9697077
# Macaulay Rd - Bellair St, Melbourne: -37.7944614, 144.9303886
# Macaulay Rd-Bellair St, Melbourne: -37.7944614, 144.9303886
# Melbourne Central, Melbourne: -37.8123652, 144.9623382
# Melbourne Central-Elizabeth St (East), Melbourne: -37.8102361, 144.9627652
# Melbourne Convention Exhibition Centre, Melbourne: -37.8252393, 144.9519166
# Monash Rd-Swanston St (West), Melbourne: -37.7985114, 144.9642048
# New Quay, Melbourne: -37.8143399, 144.9427283
# Pelham St (S), Melbourne: -37.8024538, 144.9637163
# Pelham St (South), Melbourne: -37.8024538, 144.9637163
# Princes Bridge, Melbourne: -37.8192405, 144.9683463
# QV Market-Elizabeth St (West), Melbourne: -37.8075798, 144.956785
# QV Market-Peel St, Melbourne: -37.8075798, 144.956785
# Target location not found
# QVM-Queen St (East), Melbourne: -37.8075798, 144.956785
# QVM-Therry St (South), Melbourne: -37.8075798, 144.956785
# Queen St (West), Melbourne: 28.0716832, -80.65338779999999
# Royal Pde - Grattan St, Melbourne: -37.7997236, 144.9573773
# Royal Pde-Grattan St, Melbourne: -37.7997236, 144.9573773
# Sandridge Bridge, Melbourne: -37.82003419999999, 144.963055
# Southbank, Melbourne: -37.82384, 144.9624973
# Southern Cross Station, Melbourne: -37.81839, 144.9525
# Spencer St-Collins St (North), Melbourne: -37.8189887, 144.9541878
# Spencer St-Collins St (South), Melbourne: -37.81848129999999, 144.9538201
# Spring St - Flinders St (West), Melbourne: -37.8153504, 144.9744556
# Spring St- Flinders St (West), Melbourne: -37.8153504, 144.9744556
# St Kilda Rd-Alexandra Gardens, Melbourne: -37.8204318, 144.9721339
# State Library, Melbourne: -37.8098087, 144.9651897
# State Library - New, Melbourne: -37.8098087, 144.9651897
# State Library-New, Melbourne: -37.8098087, 144.9651897
# Swanston St - City Square, Melbourne: -37.8058235, 144.9631138
# Swanston St - RMIT Building 14, Melbourne: -37.8075936, 144.9632783
# Swanston St - RMIT Building 80, Melbourne: -37.8081454, 144.9626885
# The Arts Centre, Melbourne: -37.820183, 144.9681048
# Tin Alley-Swanston St (West), Melbourne: -37.7967761, 144.9646266
# Town Hall (West), Melbourne: 28.0716832, -80.65338779999999
# Target location not found
# Waterfront City, Melbourne: -37.8128397, 144.9382043
# Webb Bridge, Melbourne: -37.823352, 144.9473047
# Westwood Place, Melbourne: -37.8127086, 144.9715452

# %%
# create new df for location coordinate

location_dict = {
    "location": location,
    "Lat": latitude,
    "Lon": longitude,
    }
location_data_dict = pd.DataFrame(location_dict)

location_data_dict.head()
# Out:
#                          location        Lat         Lon
# 0                   231 Bourke St -37.813399  144.966830
# 1                    Alfred Place -37.814340  144.970194
# 2                  Birrarung Marr -37.818735  144.974262
# 3  Bourke St - Spencer St (North) -37.817061  144.953344
# 4  Bourke St - Spencer St (South) -37.817107  144.953179

# %%
# merging foot traffic data and coord data

data_summary_2021 = location_data_dict.merge(results_2021_md_groupby_df,how="left", on="location" )
data_summary_2021.to_csv("datasummary21.csv")
data_summary_2021.head(10)
# Out:
#                          location        Lat         Lon  \
# 0                   231 Bourke St -37.813399  144.966830
# 1                    Alfred Place -37.814340  144.970194
# 2                  Birrarung Marr -37.818735  144.974262
# 3  Bourke St - Spencer St (North) -37.817061  144.953344
# 4  Bourke St - Spencer St (South) -37.817107  144.953179
# 5                Bourke St Bridge -37.815960  144.957202
# 6     Bourke St-Russell St (West) -37.815960  144.957202
# 7      Bourke Street Mall (North) -37.813769  144.964438
# 8      Bourke Street Mall (South) -37.813769  144.964438
# 9  Chinatown-Lt Bourke St (South) -37.813237  144.962778
#
#    Midday foottrafic 2021
# 0                729886.0
# 1                185084.0
# 2                320080.0
# 3                641481.0
# 4                 33935.0
# 5                481068.0
# 6                703647.0
# 7               2065840.0
# 8               1343311.0
# 9                352403.0

# %%
# creating google heatmap

# location & foot traffic input
lat_long = data_summary_2021[["Lat", "Lon"]]
foottrafic = data_summary_2021["Midday foottrafic 2021"]

# Plot Heatmap
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(lat_long, weights=foottrafic, max_intensity=2000000)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
