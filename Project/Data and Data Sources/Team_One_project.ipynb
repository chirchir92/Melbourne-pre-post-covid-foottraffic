# %%
# Dependencies
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import gmaps

# %%
file = "Resources/sampleData.csv"

# %%
#URL for GET requests to retrieve Pedestrian Sensor Data 
#sensor_locations_url = "https://data.melbourne.vic.gov.au/resource/h57g-5234.json"

# %%
# Pretty print JSON for all launchpads
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True)).head()
# Out:
# [
#     {
#         "date_time": "2019-11-01T17:00:00.000",
#         "day": "Friday",
#         "hourly_counts": "300",
#         "id": "2887628",
#         "mdate": "1",
#         "month": "November",
#         "sensor_id": "34",
#         "sensor_name": "Flinders St-Spark La",
#         "time": "17",
#         "year": "2019"
#     },
#     {
#         "date_time": "2019-11-01T17:00:00.000",
#         "day": "Friday",
#         "hourly_counts": "604",
#         "id": "2887629",
#         "mdate": "1",
#         "month": "November",
#         "sensor_id": "39",
#         "sensor_name": "Alfred Place",
#         "time": "17",
#         "year": "2019"
#     },
#     {
#         "date_time": "2019-11-01T17:00:00.000",
#         "day": "Friday",
#         "hourly_counts": "216",
#         "id": "2887630",
#         "mdate": "1",
#         "month": "November",
#         "sensor_id": "37",
#         "sensor_name": "Lygon St (East)",
#         "time": "17",
#         "year": "2019"
# ...

# %%
# set up to 
#1. Import required data fields from each data sets and create and store in a data frames 
#2. Only import data from Jan 1 2018

# %%
# Consider how to link data 
# Merge required fields from each data frame to create one data set -

# %%
# URL for GET requests to retrieve Pedestrian Data
url = "https://data.melbourne.vic.gov.au/resource/b2ak-trbp.json"

# %%
# Pretty print JSON for all launchpads
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True)).head()

# %%
#create parameter dictionary 

#sensor readings
        # params = {
        #     "date_time": date_time
        #     "time": time
        #     "day": day_of_week,
        #     "mdate": month-date
        #     "month": month 
        #     "id": reading_id
        #     "sensor_id": sensor_id
        #     "sensor_name": sensor_name
        #     "hourly_counts": hourly_counts, 
        # }    
#sensor Locations 
        # sensor_id
        # sensor_description
        # sensor_name
        # installation_date
        # status - Status of each sensor (A = Active I = Inactive R = Removed)
        # note
        # direction_1
        #direction_2
        #latitude
        #longitude
        #location The latitude and longitude of each sensor

        #response = requests.get(base_url, params=params)
        
        
#businesses
